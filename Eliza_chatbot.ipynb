# %%
#1.1 (0 points) Load one text file.

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
filename2 = 'Harrypotter.txt'
file = open(filename2, 'rt')
text = file.read()
file.close()

# %%
#1.2 (1 point) Tokenize sentences and words. Print lens of sentences and tokens and only print
#the first 20 words

# %%
word_token =word_tokenize(text)
print("number of words:{}".format(len(word_token)))
print(word_token[:20])
sent_token =sent_tokenize(text)
print("number of sentences:{}".format(len(sent_token)))
# Out:
# number of words:98782
# ['Harry', 'Potter', 'and', 'the', 'Sorcerer', "'s", 'Stone', 'CHAPTER', 'ONE', 'THE', 'BOY', 'WHO', 'LIVED', 'Mr.', 'and', 'Mrs.', 'Dursley', ',', 'of', 'number']
# number of sentences:6394

# %%
#1.3 (1 point) Remove punctuations. Only print the first 20 words

# %%
tokens = [w.lower() for w in word_token]
import string
import re
words = re.split(r'\W+', text)
tokens = [w.lower() for w in words]
print(tokens[:20])
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]
words1 = [word for word in stripped if word.isalpha()]
print("Number of words after punctuation:{}".format(len(words1)))
# Out:
# ['harry', 'potter', 'and', 'the', 'sorcerer', 's', 'stone', 'chapter', 'one', 'the', 'boy', 'who', 'lived', 'mr', 'and', 'mrs', 'dursley', 'of', 'number', 'four']
# Number of words after punctuation:80645

# %%
#1.4 (1 point)Remove stop words and count the distinct cleaned words.

# %%
from nltk.corpus import stopwords
from nltk.probability import FreqDist
stop_words = set(stopwords.words('english'))
Notstopwords= [w for w in words1 if not w in stop_words]
FreqDist1 =FreqDist(Notstopwords)
print("FreqDist with {} samples and {} outcomes".format(len(FreqDist1),len(Notstopwords)))
# Out:
# FreqDist with 5617 samples and 40784 outcomes

# %%
#1.5 (1 point) Lemmatize the cleaned words and count the distinct lemmatized words. What’s
#different from 1.4? Please clearly explain.

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_output =[lemmatizer.lemmatize(w) for w in Notstopwords]
Fdist =FreqDist(lemmatized_output)
print("FreqDist with {} samples and {} outcomes".format(len(Fdist),len(lemmatized_output)))
print(lemmatized_output[:20])
# Out:
# FreqDist with 5098 samples and 40784 outcomes
# ['harry', 'potter', 'sorcerer', 'stone', 'chapter', 'one', 'boy', 'lived', 'mr', 'mr', 'dursley', 'number', 'four', 'privet', 'drive', 'proud', 'say', 'perfectly', 'normal', 'thank']

# %%
# 1.6 (1 point) Calculate the word distribution and plot and list only top 15 words.

# %%
import nltk
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context
nltk.download('wordnet')
nltk.download('omw-1.4')
from collections import Counter

    
Counter(Notstopwords).most_common(15)
freq_dist = nltk.FreqDist(Notstopwords)
print(len(freq_dist))
print(freq_dist.most_common(15))
freq_dist.plot(15)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/prakrutikothari/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/prakrutikothari/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 5617
# [('harry', 1327), ('said', 794), ('ron', 429), ('hagrid', 370), ('hermione', 270), ('back', 261), ('one', 257), ('know', 212), ('got', 199), ('could', 198), ('like', 194), ('get', 194), ('professor', 181), ('see', 180), ('snape', 172)]
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
#2.1 (1.5 points) Follow the wordcloud simple example to generate the word cloud without
#stopwords directly from the original text and show it. Note that you must remove the
#stopwords

# %%
from wordcloud import WordCloud,STOPWORDS
wordcloud = WordCloud(stopwords=STOPWORDS).generate(text)
plt.figure()
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#2.2 (1.5 points) Generate the word cloud for the processed data in Task 1 and show the image.

# %%
wordcloud = WordCloud().generate_from_frequencies(Fdist)
plt.figure()
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#2.3 (1 point) Compare the above two word clouds and what difference do you find? Please
#clearly explain why.

# %%
#We see bigrams and unigrams for the task 2.1 and as we have first tokenized the text, and then count the frequency we dont see the bigrams.

# %%
#3.1 Based on your experience with these NLP tasks, please compare with text data processing
#and numeric data processing. 
# According to me, text data processing needs more processing compared to numbers. and text and numeric data processing 
#are somewhat related to each other as text are converted to numbers for preprocessing.
